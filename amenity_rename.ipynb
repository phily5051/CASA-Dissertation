# %% [markdown]
# # Amenity categorisation

# %%
import geopandas as gpd

# %%
pwd()
# Out:
# '/home/jovyan/work/Desktop/UCL/Term 2/UCL Dissertation/Dissertation_R'

# %%
data = gpd.read_file('data/pois/output.geojson')

# %%
data1 = gpd.read_file('data/pois/pois_london.geojson')

# %%
data.head(n=10)
# Out:
#         osmid      amenity                  name X15minute_6_urban_service  \
# 0  10698810.0     post_box  Kingston upon Thames                    Living
# 1  10702727.0     post_box  Kingston upon Thames                    Living
# 2  26038523.0     post_box  Kingston upon Thames                    Living
# 3  30480213.0     post_box  Kingston upon Thames                    Living
# 4  30482156.0     post_box  Kingston upon Thames                    Living
# 5  30483267.0     post_box  Kingston upon Thames                    Living
# 6  30483366.0          pub  Kingston upon Thames             Entertainment
# 7  30484259.0  post_office  Kingston upon Thames                    Living
# 8  30512931.0          pub  Kingston upon Thames             Entertainment
# 9  30629721.0     post_box  Kingston upon Thames                    Living
#
#   detailed_urban_service   GSS_CODE  HECTARES       lon        lat  \
# 0  Civic_infrastructures  E09000021  3726.117 -0.301778  51.410805
# ...

# %%
unique_amenities = data['amenity'].nunique()
unique_amenities
# Out:
# 597

# %%
# Define the mapping to correct the mis-classified amenity names
amenity_mapping = {
    'advice_bureau': 'Commerce',
    'estate_agent': 'Commerce',
    'fuel': 'Living',
    'funeral': 'Living',
    'hunting_stand': 'Living',
    'waste_basket': 'Living',
    'wedding_venue': 'Living',
    'office': 'Commerce',
    'key_cutting':'Commerce',
    'local_government':'Living',
    'mobile_phone':'Commerce',
    'toilets':'Living',
    'job_centre':'Commerce'
    # Add more entries here for other mis-classified names
}

# Replace the mis-classified amenity names with the correct ones
data['X15minute_6_urban_service'] = data['X15minute_6_urban_service'].replace(amenity_mapping)

# %%
import pandas as pd

# Assuming your DataFrame is called 'df'
data.loc[(data['amenity'] == 'key_cutting') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'advice_bureau') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'job_centre') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'estate_agent') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'mobile_phone') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'office') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'funeral') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'local_government') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'fuel') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'toilets') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'hunting_stand') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'waste_basket') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'Care_Agency') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'lounge') & (data['X15minute_6_urban_service'] == 'Living'), 'X15minute_6_urban_service'] = 'Entertainment'
data.loc[(data['amenity'] == 'drinking_water') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'Childrens Centre') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'information_centre') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'beauty_clinic') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'health') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'massage') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'optician') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'tanning') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Healthcare'
data.loc[(data['amenity'] == 'convenience_store') & (data['X15minute_6_urban_service'] == 'Healthcare'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'job_centre') & (data['X15minute_6_urban_service'] == 'Education'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'wedding_venue') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Living'
data.loc[(data['amenity'] == 'gym') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Healthcare'

data.loc[(data['amenity'] == 'Shisha_Lounge') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Entertainment'
data.loc[(data['amenity'] == 'alcohol') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Entertainment'
data.loc[(data['amenity'] == 'artwork') & (data['X15minute_6_urban_service'] == 'Commerce'), 'X15minute_6_urban_service'] = 'Entertainment'
data.loc[(data['amenity'] == 'bookmaker') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'books') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'composting') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'convenience_store') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'garden') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'key_cutting') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'
data.loc[(data['amenity'] == 'printing') & (data['X15minute_6_urban_service'] == 'Entertainment'), 'X15minute_6_urban_service'] = 'Commerce'

# %%
unique_amen = data['amenity'].unique()
sl = set(unique_amen)
sc = set(living) # + com + heal + edu + enter
s1 = sl - sc
s2 = s1 - set(com) - set(heal) - set(edu) - set(enter)
s2

# Classify 'school_workshop' as 'Education'
data.loc[data['amenity'] == 'school_workshop', 'X15minute_6_urban_service'] = 'Education'

# %%
living = data[data['X15minute_6_urban_service'] == 'Living']['amenity'].nunique()
living
# Out:
# 108

# %%
com = data[data['X15minute_6_urban_service'] == 'Commerce']['amenity'].nunique()
com
# Out:
# 343

# %%
heal = data[data['X15minute_6_urban_service'] == 'Healthcare']['amenity'].nunique()
heal
# Out:
# 36

# %%
edu = data[data['X15minute_6_urban_service'] == 'Education']['amenity'].nunique()
edu
# Out:
# 23

# %%
enter = data[data['X15minute_6_urban_service'] == 'Entertainment']['amenity'].nunique()
enter
# Out:
# 87

# %%
# Specify the output file path and name
output_file = 'pois_london.geojson'

# Export the GeoDataFrame to GeoJSON format
data.to_file(output_file, driver='GeoJSON')

# %%
# Load the file
file_path = '/content/drive/MyDrive/data/pois_london.geojson'
df = gpd.read_file(file_path)

# Initial 874 amenity types
unique_amenities = df['amenity'].unique()
len(unique_amenities)

# Replace specific values with 'post_box' in place
df['amenity'].replace(['post_depot', 'vending_machine;post_box', 'letter_box'], 'post_box', inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#871
replace_dict = {
    'parking_entrance': 'parking',
    'parking_space': 'parking',
    'motorcycle_parking': 'parking',
    'scooter_parking': 'parking',
    'bicycle_parking': 'parking',
    'micro_scooter_parking': 'parking',
    'post_box;bicycle_parking': 'parking'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#865
# Replace with Pub and University
replace_dict = {
    'disused_pub': 'pub',
    'dead_pub': 'pub',
    'old_pub': 'pub',
    'tuition': 'university',
    'tution': 'university'
}
df['amenity'].replace(replace_dict, inplace=True)


replace_dict = {
    'atm;telephone': 'telephone',
    'waste_disposal': 'waste_basket', 
    'junk': 'waste_basket', 
    'litter_bin': 'waste_basket', 
    'waste': 'waste_basket',
    'dog_litter_box': 'pet_waste_basket',
    'dog_waste_basket': 'pet_waste_basket'
}

df['amenity'].replace(replace_dict, inplace=True)

replace_dict = {
    'former_fast_food': 'fast_food',
    'coffee': 'cafe',
    'bathroom': 'toilets',
    'temporary_toilet_site': 'toilets',
    'bathrooms': 'toilets',
    'learned_society;library': 'library',
    'mobile_library': 'library',
    'toy_library': 'library',
    'public_building;place_of_worship': 'place_of_worship',
    'religion': 'place_of_worship',
    'religious_precinct': 'place_of_worship',
    'bar;restuarant': 'restaurant',
    'charging_station': 'fuel',
    'coalmerchant': 'fuel',
    'gas': 'fuel',
    'coal_merchant': 'fuel',
    'seating': 'bench',
    'club': 'nightclub',
    'bar;nightclub': 'nightclub',
    'watering_place': 'drinking_water',
    'water_point': 'drinking_water',
    'water_pump': 'drinking_water',
    'water_fountain': 'drinking_water', 
    'beer_garden': 'biergarten',
    'parcel_locker': 'locker',
    'garden_centre': 'garden',
    'gardens': 'garden',
    'green' :'garden',
    'market': 'marketplace'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#823
replace_dict = {
    'studio;theatre': 'theatre',
    'court_house' : 'courthouse',
    'convenience': 'convenience_store',
    'chemist;convenience': 'convenience_store',
    'confectionery;convenience': 'convenience_store',
    'butcher;bakery;convenience': 'convenience_store',
    'greengrocer;convenience': 'convenience_store',
    'funeral_directors': 'funeral',
    'car;car_repair': 'car_repair',
    'car_repair;car': 'car_repair',
    'hairdresser;beauty' : 'hairdresser',
    'vacant;bakery': 'bakery',
    'gallery_/_bookshop': 'books',
    'gallery / bookshop': 'books',
    'phone,clothes': 'clothes',
    'charity;clothes': 'clothes',
    'convenience;alcohol'  : 'alcohol',
    'yes': 'doityourself',
    'convenience;doityourself': 'doityourself',
    'gift;sweets;confectionery': 'confectionary',
    'chemist': 'grocery',
    'greengrocer': 'grocery',
    'grocer': 'grocery', 
    'butcher;greengrocer': 'grocery',
    'fruiterer;greengrocer': 'grocery',
    'letting_agent': 'estate_agent',
    'viewing_platform': 'estate_agent',
    'convenience;mobile_phone' :'mobile_phone',
    'e-cigarette;mobile_phone': 'mobile_phone',
    'mobile':'mobile_phone',
    'phone': 'mobile_phone',
    'shoe_shine':  'shoes',
    'leather;shoes': 'shoes',
    'self_storage': 'storage',
    'storage_rental': 'storage',
    'bookbinders': 'bookmaker'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#789
replace_dict = {
    'natural_health': 'health',
    'dentist;optician' : 'optician',
    'bedding'    : 'bed' ,
    'mixed' : 'variety_store',
    'greengrocer;florist':  'florist',
    'garden_centre;florist':  'florist',
    'bathroom_furnishing;kitchen': 'kitchen',
    'pastry': 'patisserie' ,
    'interior_decoration': 'interior_design',
    'interior': 'interior_design',
    'design_interior' : 'interior_design',
    'decoration': 'interior_design',
    'e-cigarette': 'tobacco',
    'mobile_phone;e-cigarette': 'tobacco',
    'tobacco;e-cigarette': 'tobacco',
    'former_jewelry': 'jewelry',
    'bijouterie'  : 'jewelry',
    'jewellery': 'jewelry',
    'laundry': 'launderette',
    'ironing': 'launderette',
    'dry_cleaning;laundry': 'launderette',
    'dry_cleaners': 'launderette',
    'laundrette': 'launderette', 
    'clothes_dryer': 'launderette',
    'laundromat': 'launderette',
    'computer;dry_cleaning': 'launderette',
    'laundry;dry_cleaning': 'launderette',
    'dry_cleaning' :'launderette',
    'shoe_repair;dry_cleaning': 'launderette',
    'photo': 'photography',
    'homeware': 'houseware',
    'household_products': 'houseware',
    'homewares': 'houseware',
    'porcelain_homeware': 'houseware',
    'household': 'houseware',
    'household_goods': 'houseware'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#752
replace_dict = {
    'beauty;massage': 'massage',
    'massage_parlour': 'massage',
    'art;frame'   : 'frame' ,
    'wood_floor' : 'flooring',
    'floors':  'flooring',
    'information':  'information_centre',
    'art_gallery': 'gallery',
    'art_studio': 'gallery' ,
    'arts': 'art',
    'aquariums': 'aquarium',
    'housing_office' : 'Housing_Office',
    'cyber_cafe': 'internet_cafe',
    'ticket': 'ticket_office',
    'ticket_booth': 'ticket_office',
    'wedding': 'wedding_venue',
    'advice': 'advice_bureau',
    'place_of_worship;conference_centre'  : 'conference_centre',
    'nursing_home': 'nursery',
    'cobblers;shoe_repairs;bag;locksmiths': 'locksmith',
    'tiles': 'tile',
    'ceramic_tiles': 'tile',
    'haberdashery': 'sewing',
    'homeopathy': 'alternative_medicine', 
    'alternative_health': 'alternative_medicine',
    'everything': 'wholesale',
    'glaziery': 'glass',
    'doors;glaziery': 'glass',
    'glass_mosaic' :'glass',
    'glassmaker': 'glass',
    'optician;hearing_aids': 'hearing_aids',
    'computer repair': 'computer_repair',
    'computer_repairs': 'computer_repair',
    'fancy_dress;balloon': 'balloon',
    'glaziery;doors': 'doors',
    'pet': 'pet_grooming',
    'garden_centre;pet': 'pet_grooming'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#717
replace_dict = {
    'blinds': 'window_blind',
    'furnishings':'furnishing',
    'bathroom_furnishing'   : 'furnishing' ,
    'kitchen;bathroom_furnishing' : 'furnishing',
    'tiles;bathroom_furnishing':  'furnishing',
    'Home_furnishings':  'furnishing',
    "children's_furnishing": 'furnishing',
    'bathroom_fittings': 'furnishing' ,
    'mobile_phone;hairdresser_supply': 'hairdresser_supply',
    'Hairpieces': 'hairdresser_supply',
    'domestic_appliances' : 'appliance',
    'jewelry;fabric': 'fabric',
    'cashncarry': 'cash_and_carry',
    'confectionery;tea': 'tea',
    'gun': 'weapons',
    'builders_merchant': 'building_materials',
    'building_supplies'  : 'building_materials',
    'building_merchants': 'building_materials',
    'care_home': 'Care_Agency',
    'deaf': 'Care_Agency',
    'community_centre;preschool': 'prep_school',
    'fitness': 'gym',
    'health_club': 'gym', 
    'court_yard': 'courtyard',
    'court-yard': 'courtyard',
    'comics': 'comic',
    'household_linen': 'linen',
    'recruitment' : 'employment_agency'    ,
    'jobs': 'employment_agency'    ,
    'clothes;charity_shop;second_hand': 'second_hand',
    'Card_&_Posters': 'printing',
    'greeting_cards': 'printing',
    'print': 'printing',
    'cards': 'printing',
    'printers': 'printing',
    'posters': 'printing',
    'T-Shirt_Printer': 'printing',
    '3d_printing': 'printing',
    'printer': 'printing'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#678
replace_dict = {
    'plumbers': 'plumbing',
    'plumbing_and_heating': 'plumbing',
    'plumber'   : 'plumbing' ,
    'Plumbing_&_Heating' : 'plumbing',
    'serviced_office':  'office',
    'electricals':  'electrical' ,
    'windows': 'window_service',
    'window_tinting': 'window_service' ,
    'window_construction': 'window_service',
    'fixme': 'repair',
    'job_agent' : 'job_centre'    ,
    'jobcentre': 'job_centre'    ,
    'shisha':'Shisha_Lounge',
    'waste_dump_site': 'sanitary_dump_station' ,
    'watches': 'watch',
    'motorcycle_rental': 'rental',
    'escooter_rental'   : 'rental',
    'bicycle_rental' : 'rental',
    'boat_rental' : 'rental',
    'van_rental'  : 'rental',
    'car_rental' : 'rental',
    'car_sharing'  : 'rental',
    'private_hire_cars': 'rental', 
    'car_pooling': 'rental',
    'photographic_studio': 'photo_studio',
    'car_detailing': 'car_parts',
    'wellness': 'spa',
    'lounger' : 'lounge'    ,
    'departure_lounge': 'lounge'   ,
    'arrivals_lounge': 'lounge',
    'beauty_treatment': 'beauty_clinic',
    'beauty': 'beauty_clinic',
    'financial_advice': 'finance',
    'financial': 'finance',
    'suntan': 'tanning',
    'solicitors':    'solicitor',
    'communications':      'communication',
    'meditation_centre': 'meditation',
    'hunting': 'hunting_stand',
    'shared_office': 'coworking_space',
    'coworking': 'coworking_space',
    'catering_equipment': 'catering',
    'discount': 'discount_shop'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
#635
replace_dict = {
    'plants': 'composting',
    'accountants': 'accountant',
    'children_centre'   : 'Childrens Centre' ,
    'children_play_centre' : 'Childrens Centre',
    'watchmaker':  'clockmaker',
    'petfood': 'pet_food' ,
    'off_license': 'off_licence',
    'newborns': 'new_age' ,
    'boot_brush': 'boot_cleaner',
    'wood': 'carpenter',
    'woodwork' : 'carpenter'  ,
    'municipal': 'local_government'    ,
    'civic_centre':'local_government',
    'ironmonger': 'iron_monger'  ,
    'workwear': 'clothing',
    'Maternity_Wear': 'clothing',
    'Childrenswear'   : 'clothing',
    'Ballet_&_Dancewear' : 'clothing',
    'shoe_repair;key_cutting' : 'key_cutting',
    'key_cutter'  : 'key_cutting',
    'http://twickenham-fine-ales.co.uk/toursbar/'  : 'brewery',
    'kitchen_knives'  : 'kitchenware',
    'cookware': 'kitchenware', 
    'cooking_equipment': 'kitchenware',
    'kitchen_equipment': 'kitchenware',
    'Art_Supplies': 'art_supplies',
    'Bespoke_Rugs': 'rugs',
    'learned_society' : 'society'    ,
    'dress_hire': 'dresswear_hire'   ,
    'suit_hire': 'dresswear_hire',
    'car_accessories': 'accessories',
    'fashion_accessories': 'accessories',
    'clothing_accessories': 'accessories',
    'Card_Machines_&_Accessories': 'accessories',
    'Wine_Storage_and Accessories': 'accessories',
    'left_luggage':    'lost_property',
    'souvenirs':      'souvenir',
    'sports;gift;souvenir': 'souvenir',
    'shopping': 'shopping_centre',
    'archives': 'archive'
}

df['amenity'].replace(replace_dict, inplace=True)

# Now check the unique values
unique_amenities = df['amenity'].unique()
print(len(unique_amenities))
